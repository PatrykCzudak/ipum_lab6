# %% [markdown]
# # Laboratory 9 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Learning objectives
#
# 1. **Implement automated experiment tracking** using MLflow autologging capabilities with scikit-learn, enabling automatic capture of model parameters and metrics without writing additional tracking code.
#
# 2. **Configure manual logging strategies** for PyTorch experiments, implementing custom tracking for metrics, parameters, and artifacts throughout the training process.
#
# 3. **Analyze and compare experimental results** using MLflow tracking UI and programmatic APIs to identify optimal model configurations and understand performance patterns.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration

# %% [markdown]
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.

# %% [markdown]
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5000
# ```
# Important: Keep this terminal window open. The MLflow server will continue running and be accessible at http://localhost:5000

# %% [markdown]
# To verify if the server runs properly, let's connect to git:

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5000")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5000

# %% [markdown]
# Setup complete! You now have the MLflow server running as a separate process, and `mlflow` library in this Jupyter Notebook is connected to it. Just note that we had to use the proper host and port - if you want to connect to a remote server, modify the tracking URI appropriately.

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here. As we have temporal data, the best way to evaluate our model is time (chronological) split, where the newest data is used for testing. We will assume that we have the data for years 2006 and 2007, and evaluate using data from 2008.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a buch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2025/06/29 12:41:53 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.0. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2025/06/29 12:41:55 INFO mlflow.tracking.fluent: Experiment with name 'ames-housing-autolog' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/patryk/ipum/ipum_lab6/mlflow-artifacts/1', creation_time=1751193715654, experiment_id='1', last_update_time=1751193715654, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor


models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score


def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2025/06/29 12:42:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.880 ± 0.037
# 🏃 View run Ridge Regression at: http://localhost:5000/#/experiments/1/runs/2a1121371f3742aca143192cf66e50d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.726 ± 0.080
# 🏃 View run Decision Tree at: http://localhost:5000/#/experiments/1/runs/2ce35c37f8564a4b8ed80e2ecb7e768f
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38325.06
#   MAE: 26034.07
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.656 ± 0.050
# 🏃 View run K-Nearest Neighbors at: http://localhost:5000/#/experiments/1/runs/ffe1ee9b1e7a40b3992da5dc981263f9
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:42:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:09 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:10 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25896.23
#   MAE: 15509.71
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.870 ± 0.043
# 🏃 View run Random Forest at: http://localhost:5000/#/experiments/1/runs/88a68e3d37dd4531b4dbaec74d18804e
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:42:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:42:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gradient Boosting:
#   RMSE: 21572.13
#   MAE: 13809.38
#   R^2: 0.919
#   CV R^2 (mean ± std): 0.898 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5000/#/experiments/1/runs/5289ba38065b4a58864666399ed41952
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Since we obtained quite satisfactory results, our imaginary client would like to be sure that we do our best and wants us to compare many more combinations.
#
# Your task is to run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
#
# Did you manage to beat the previous approaches?

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

new_models = [
    ("RF_200_estimators_d10",
        RandomForestRegressor(n_estimators=200, max_depth=10, random_state=42)),
    ("GBR_200_estimators_lr0.05",
        GradientBoostingRegressor(n_estimators=200, learning_rate=0.05, random_state=42)),
    ("ExtraTrees_100_sqrt",
        ExtraTreesRegressor(n_estimators=100, max_features="sqrt", random_state=42)),
    ("KNN_5_distance",
        KNeighborsRegressor(n_neighbors=5, weights="distance")),
    ("SVR_rbf_C1_e0.1",
        SVR(kernel="rbf", C=1.0, epsilon=0.1))
]

fit_sklearn_models_with_cv(new_models, X_train, X_test, y_train, y_test)
# Out:
# 2025/06/29 12:47:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:16 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:18 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:22 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:25 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# RF_200_estimators_d10:
#   RMSE: 25792.66
#   MAE: 15713.17
#   R^2: 0.884
#   CV R^2 (mean ± std): 0.869 ± 0.041
# 🏃 View run RF_200_estimators_d10 at: http://localhost:5000/#/experiments/1/runs/278ca9ca3a06496fae191f36dc18c042
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:47:26 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:27 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:28 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:29 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:30 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:30 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# GBR_200_estimators_lr0.05:
#   RMSE: 21600.95
#   MAE: 13792.64
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.897 ± 0.032
# 🏃 View run GBR_200_estimators_lr0.05 at: http://localhost:5000/#/experiments/1/runs/921f8ac846284ab6a5c4303578b18b69
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:47:31 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:31 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:31 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# ExtraTrees_100_sqrt:
#   RMSE: 24301.84
#   MAE: 16047.70
#   R^2: 0.897
#   CV R^2 (mean ± std): 0.844 ± 0.047
# 🏃 View run ExtraTrees_100_sqrt at: http://localhost:5000/#/experiments/1/runs/95ae2552ea444e5fbc654abcc926a60c
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:47:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:33 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:33 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# KNN_5_distance:
#   RMSE: 38861.94
#   MAE: 26027.63
#   R^2: 0.736
#   CV R^2 (mean ± std): 0.664 ± 0.070
# 🏃 View run KNN_5_distance at: http://localhost:5000/#/experiments/1/runs/d83515a0540345d884d1b665fb988df7
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/29 12:47:33 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:33 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:34 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:34 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/29 12:47:34 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# SVR_rbf_C1_e0.1:
#   RMSE: 77482.01
#   MAE: 54914.40
#   R^2: -0.051
#   CV R^2 (mean ± std): -0.129 ± 0.135
# 🏃 View run SVR_rbf_C1_e0.1 at: http://localhost:5000/#/experiments/1/runs/3032cdde089341348c301291bce0d168
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Manual logging with PyTorch

# %% [markdown]
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but many people prefer or often need low-level control of pure PyTorch. Thus, we will focus on this approach, which also will teach us more about powerful MLflow capabilities.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# 2025/06/29 12:51:31 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/patryk/ipum/ipum_lab6/mlflow-artifacts/2', creation_time=1751194291373, experiment_id='2', last_update_time=1751194291373, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation

# %% [markdown]
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them!

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model

# %% [markdown]
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 27229.65, MAE: 20778.10 R^2: 0.880
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 30428.84, MAE: 20555.09 R^2: 0.843
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 32255.64, MAE: 25830.53 R^2: 0.853
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 36798.89, MAE: 28542.72 R^2: 0.776
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 30886.14, MAE: 23621.97 R^2: 0.852
#
# Cross-validation complete. Mean R^2: 0.841 (+/- 0.035)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.841 (+/- 0.035)
#
# Cross-Validation Performance:
#   R^2: 0.866
#   RMSE: 27676.01
#   MAE: 20253.73
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5000/#/experiments/2/runs/ad569ecfed8c4a1594e41c04e1f2f2af
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %% [markdown]
# Go to the MLflow dashboard and take a look at logged values. Focus particularly on the "Model metrics" tab, which for neural networks visualizes the progress of iterative training.

# %% [markdown]
# ### 3.3 Hyperparameter optimization with MLflow

# %% [markdown]
# Now, we will use MLflow logging and visualization capabilities to help us tune hyperparameters of neural networks. This is one of the major applications of experiment tracking frameworks. As neural networks have many hyperparameters, with complex interactions, and training them many times is very computationally intensive, we want to use human judgment, based on plots and metrics, to guide our choices in further experiments.
#
# A quick recap on main hyperparameters of MLPs:
#
# 1. **Learning rate:**
#    - typically 1e-5 to 1e-1
#    - too high: loss explodes, model diverges
#    - too low: slow convergence, might get stuck
#    - sweet spot: fast convergence to good minimum
#
# 3. **Model size** - number of hidden units here:
#    - typically 32 to 512
#    - too few: underfitting, can't capture patterns
#    - too many: overfitting, slow training, diminishing returns
#    - consider: more features need more capacity
#
# 5. **Dropout rate:**
#    - typically 0.0 to 0.5
#    - 0.0: no regularization, risk overfitting
#    - too high: underfitting, loses important information
#    - purpose: prevents over-reliance on specific neurons
#
# 7. **Batch size:**
#    - typically 16 to 128
#    - small: noisy gradients, often better generalization, slower
#    - large: stable gradients, faster training, needs more memory, may overfit
#    - trade-off: speed vs generalization
#
# 9. **Number of epochs:**
#    - too few: underfitting
#    - too many: overfitting
#    - optimal: when validation loss stops improving
#    - watch validation loss

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# Example:
#
# ```python
#
# base_config = {
#     # or any other your own architecture :) we definitely recommend to experiment by yourselves
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],
#     "num_samples": X_train.shape[0],
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# configs = {
#      {
#         "name": "first_run_or_other_your_own_meaningful_name",
#         "hidden_units": 128,
#          ...
#      },
#     {
#         "name": "second_run_or...",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     }
# }
#
# for config in configs:
#     # in python we can in elegant way merge two dicts using "|" operator - finally...
#     # old merging method {**base_config, **config} - ugly :(
#     training_config = base_config | config
#     trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
#     results = trainer.fit(X_train, y_train, X_test, y_test)
# ```
#
# or just manually and incrementally:
#
# ```python
# new_config = {
#     "name": "second_run_or...",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | config
# trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
# results = trainer.fit(X_train, y_train, X_test, y_test)
# ```

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

configs = [
    {
        "name": "Malutki (64 HU, lr=0.001, DO=0, ep=100, bs=32)",
        "hidden_units": 64,
        "dropout": 0.0,
        "learning_rate": 0.001,
        "epochs": 100,
        "batch_size": 32,
    },
    {
        "name": "Mały (128 HU, lr=0.01, DO=0.1, ep=150, bs=32)",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "Sredni (256 HU, lr=0.03, DO=0.2, ep=150, bs=64)",
        "hidden_units": 256,
        "dropout": 0.2,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 64,
    },
    {
        "name": "Gleboki (128 HU, lr=0.005, DO=0.3, ep=200, bs=16)", #bo duzo epok
        "hidden_units": 128,
        "dropout": 0.3,
        "learning_rate": 0.005,
        "epochs": 200,
        "batch_size": 16,
    },
    {
        "name": "Szeroki (512 HU, lr=0.05, DO=0.5, ep=100, bs=64)", #bo bużo neuronów 
        "hidden_units": 512,
        "dropout": 0.5,
        "learning_rate": 0.05,
        "epochs": 100,
        "batch_size": 64,
    },
    {
        "name": "Szybki (256 HU, lr=0.1, DO=0.1, ep=75, bs=128)", #bo duzy baych i lr
        "hidden_units": 256,
        "dropout": 0.1,
        "learning_rate": 0.1,
        "epochs": 75,
        "batch_size": 128,
    },
    {
        "name": "Stabilny (32 HU, lr=0.0001, DO=0, ep=200, bs=16)", #maly z duza iloscia epok i malym Lr
        "hidden_units": 32,
        "dropout": 0.0,
        "learning_rate": 0.0001,
        "epochs": 200,
        "batch_size": 16,
    },
    {
        "name": "Duzy_dopout (128 HU, lr=0.02, DO=0.4, ep=125, bs=32)",
        "hidden_units": 128,
        "dropout": 0.4,
        "learning_rate": 0.02,
        "epochs": 125,
        "batch_size": 32,
    },
    {
        "name": "Blyskawiczny (512 HU, lr=0.005, DO=0.2, ep=50, bs=128)",
        "hidden_units": 512,
        "dropout": 0.2,
        "learning_rate": 0.005,
        "epochs": 50,
        "batch_size": 128,
    },
    {
        "name": "Wytrzymaly (64 HU, lr=0.02, DO=0.5, ep=175, bs=16)", #bo dlugie treningi
        "hidden_units": 64,
        "dropout": 0.5,
        "learning_rate": 0.02,
        "epochs": 175,
        "batch_size": 16,
    },
]

# %%
for config in configs:
    training_config = base_config | config 
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Malutki (64 HU, lr=0.001, DO=0, ep=100, bs=32)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 70439.85, MAE: 36405.41 R^2: 0.194
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 53963.67, MAE: 34638.93 R^2: 0.507
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 45268.97, MAE: 33955.11 R^2: 0.711
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 52476.60, MAE: 36668.99 R^2: 0.544
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 56722.72, MAE: 39970.68 R^2: 0.500
#
# Cross-validation complete. Mean R^2: 0.491 (+/- 0.167)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.491 (+/- 0.167)
#
# Cross-Validation Performance:
#   R^2: 0.577
#   RMSE: 49160.49
#   MAE: 35511.75
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Malutki (64 HU, lr=0.001, DO=0, ep=100, bs=32):
#
# ==================================================
# 🏃 View run Malutki (64 HU, lr=0.001, DO=0, ep=100, bs=32) at: http://localhost:5000/#/experiments/2/runs/965a2ca197904d7eaf29a468dfd7c8eb
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Mały (128 HU, lr=0.01, DO=0.1, ep=150, bs=32)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 53840.98, MAE: 35375.62 R^2: 0.529
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 61098.27, MAE: 42833.27 R^2: 0.369
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 49515.08, MAE: 38921.59 R^2: 0.654
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 85875.53, MAE: 60700.67 R^2: -0.221
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 97529.19, MAE: 75317.70 R^2: -0.479
#
# Cross-validation complete. Mean R^2: 0.170 (+/- 0.442)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.170 (+/- 0.442)
#
# Cross-Validation Performance:
#   R^2: -1.117
#   RMSE: 109977.80
#   MAE: 85703.52
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Mały (128 HU, lr=0.01, DO=0.1, ep=150, bs=32):
#
# ==================================================
# 🏃 View run Mały (128 HU, lr=0.01, DO=0.1, ep=150, bs=32) at: http://localhost:5000/#/experiments/2/runs/04c4ded2398c47018d623918ab1765d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Sredni (256 HU, lr=0.03, DO=0.2, ep=150, bs=64)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 79196.51, MAE: 69729.06 R^2: -0.019
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 43492.14, MAE: 31163.38 R^2: 0.680
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 59131.47, MAE: 46928.73 R^2: 0.507
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 416644.69, MAE: 332046.97 R^2: -27.747
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 41647.88, MAE: 31716.71 R^2: 0.730
#
# Cross-validation complete. Mean R^2: -5.170 (+/- 11.292)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -5.170 (+/- 11.292)
#
# Cross-Validation Performance:
#   R^2: 0.551
#   RMSE: 50624.83
#   MAE: 39989.91
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Sredni (256 HU, lr=0.03, DO=0.2, ep=150, bs=64):
#
# ==================================================
# 🏃 View run Sredni (256 HU, lr=0.03, DO=0.2, ep=150, bs=64) at: http://localhost:5000/#/experiments/2/runs/e24d2777d3344d29a76ae955a1e11387
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Gleboki (128 HU, lr=0.005, DO=0.3, ep=200, bs=16)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 24658.08, MAE: 17197.47 R^2: 0.901
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 31150.07, MAE: 22668.67 R^2: 0.836
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 22406.17, MAE: 15438.11 R^2: 0.929
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 25515.77, MAE: 17014.31 R^2: 0.892
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 26749.48, MAE: 16870.31 R^2: 0.889
#
# Cross-validation complete. Mean R^2: 0.889 (+/- 0.030)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.889 (+/- 0.030)
#
# Cross-Validation Performance:
#   R^2: 0.881
#   RMSE: 26036.52
#   MAE: 18191.20
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Gleboki (128 HU, lr=0.005, DO=0.3, ep=200, bs=16):
#
# ==================================================
# 🏃 View run Gleboki (128 HU, lr=0.005, DO=0.3, ep=200, bs=16) at: http://localhost:5000/#/experiments/2/runs/fe42d854f404457a9c8856a006619aec
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Szeroki (512 HU, lr=0.05, DO=0.5, ep=100, bs=64)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 27401.45, MAE: 18218.99 R^2: 0.878
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25063.53, MAE: 18012.92 R^2: 0.894
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24250.92, MAE: 16875.33 R^2: 0.917
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 30137.83, MAE: 19583.40 R^2: 0.850
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 31612.79, MAE: 20647.42 R^2: 0.845
#
# Cross-validation complete. Mean R^2: 0.877 (+/- 0.027)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.877 (+/- 0.027)
#
# Cross-Validation Performance:
#   R^2: 0.861
#   RMSE: 28151.75
#   MAE: 19715.85
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Szeroki (512 HU, lr=0.05, DO=0.5, ep=100, bs=64):
#
# ==================================================
# 🏃 View run Szeroki (512 HU, lr=0.05, DO=0.5, ep=100, bs=64) at: http://localhost:5000/#/experiments/2/runs/c74991e8d3aa4fc1aa9f4ec802712188
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Szybki (256 HU, lr=0.1, DO=0.1, ep=75, bs=128)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 79343.69, MAE: 54391.90 R^2: -0.022
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 79563.38, MAE: 66165.48 R^2: -0.071
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 48809.93, MAE: 31636.44 R^2: 0.664
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 52154.03, MAE: 39291.05 R^2: 0.550
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 34905.27, MAE: 25508.39 R^2: 0.811
#
# Cross-validation complete. Mean R^2: 0.386 (+/- 0.363)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.386 (+/- 0.363)
#
# Cross-Validation Performance:
#   R^2: 0.786
#   RMSE: 34955.63
#   MAE: 23862.07
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Szybki (256 HU, lr=0.1, DO=0.1, ep=75, bs=128):
#
# ==================================================
# 🏃 View run Szybki (256 HU, lr=0.1, DO=0.1, ep=75, bs=128) at: http://localhost:5000/#/experiments/2/runs/046976500d1547d3a6bfb6cad171ac74
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Stabilny (32 HU, lr=0.0001, DO=0, ep=200, bs=16)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 68026.37, MAE: 38032.11 R^2: 0.248
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 57136.49, MAE: 38570.34 R^2: 0.448
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 52046.45, MAE: 39552.22 R^2: 0.618
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 51685.26, MAE: 37046.90 R^2: 0.558
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 55483.36, MAE: 39603.60 R^2: 0.522
#
# Cross-validation complete. Mean R^2: 0.479 (+/- 0.128)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.479 (+/- 0.128)
#
# Cross-Validation Performance:
#   R^2: 0.494
#   RMSE: 53745.07
#   MAE: 38851.28
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Stabilny (32 HU, lr=0.0001, DO=0, ep=200, bs=16):
#
# ==================================================
# 🏃 View run Stabilny (32 HU, lr=0.0001, DO=0, ep=200, bs=16) at: http://localhost:5000/#/experiments/2/runs/2ea671215e0448b7a43342181143b720
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Duzy_dopout (128 HU, lr=0.02, DO=0.4, ep=125, bs=32)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 22069.32, MAE: 15932.77 R^2: 0.921
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 23903.03, MAE: 16924.30 R^2: 0.903
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24061.44, MAE: 16415.12 R^2: 0.918
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 26078.83, MAE: 17469.15 R^2: 0.887
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 33500.68, MAE: 23092.52 R^2: 0.826
#
# Cross-validation complete. Mean R^2: 0.891 (+/- 0.035)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.891 (+/- 0.035)
#
# Cross-Validation Performance:
#   R^2: 0.855
#   RMSE: 28757.02
#   MAE: 20823.71
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Duzy_dopout (128 HU, lr=0.02, DO=0.4, ep=125, bs=32):
#
# ==================================================
# 🏃 View run Duzy_dopout (128 HU, lr=0.02, DO=0.4, ep=125, bs=32) at: http://localhost:5000/#/experiments/2/runs/7ab0e06846c04b08ac9f1fa6ff9d2b1e
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Blyskawiczny (512 HU, lr=0.005, DO=0.2, ep=50, bs=128)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 92015.07, MAE: 43627.26 R^2: -0.375
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 59967.90, MAE: 40761.91 R^2: 0.392
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 50194.12, MAE: 38600.34 R^2: 0.645
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 55692.41, MAE: 39602.27 R^2: 0.486
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 60761.55, MAE: 42965.26 R^2: 0.426
#
# Cross-validation complete. Mean R^2: 0.315 (+/- 0.356)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.315 (+/- 0.356)
#
# Cross-Validation Performance:
#   R^2: 0.204
#   RMSE: 67418.94
#   MAE: 47508.48
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Blyskawiczny (512 HU, lr=0.005, DO=0.2, ep=50, bs=128):
#
# ==================================================
# 🏃 View run Blyskawiczny (512 HU, lr=0.005, DO=0.2, ep=50, bs=128) at: http://localhost:5000/#/experiments/2/runs/bb8a86c741c34d26a5be69df445c12ae
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for Wytrzymaly (64 HU, lr=0.02, DO=0.5, ep=175, bs=16)...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 45149.30, MAE: 29493.90 R^2: 0.669
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 54703.29, MAE: 39163.65 R^2: 0.494
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 53141.80, MAE: 36765.43 R^2: 0.602
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 45111.03, MAE: 32375.39 R^2: 0.663
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 56123.50, MAE: 40427.18 R^2: 0.510
#
# Cross-validation complete. Mean R^2: 0.588 (+/- 0.074)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.588 (+/- 0.074)
#
# Cross-Validation Performance:
#   R^2: 0.452
#   RMSE: 55950.96
#   MAE: 40435.41
# Test Set Performance:
# ==================================================
# FINAL RESULTS for Wytrzymaly (64 HU, lr=0.02, DO=0.5, ep=175, bs=16):
#
# ==================================================
# 🏃 View run Wytrzymaly (64 HU, lr=0.02, DO=0.5, ep=175, bs=16) at: http://localhost:5000/#/experiments/2/runs/d4b6185f5fe04f21af720dd33f2720b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Najlepiej wyszedł Model Gleboki. Najniższe RMSE i małe wachanie między foldami (0.03) i wysokim r^2 (im bliżej 1 tym lepiej).
#
# Kolejne są Model Szeroki i duży doprdown. Mają one podobne watości RMSE i r^2
#
# Najgorsze dwa modele to Mały r^2=0.17 i RMSE aż 109977 i Model średni (którego r^2 jest tragiczne bo -5)

# %% [markdown]
# Które zmiany pomogły, a które zaszkodziły
#
# | Zmiana                            | Efekt pozytywny                                                  | Efekt negatywny                                                                    |
# | --------------------------------- | ---------------------------------------------------------------- | ---------------------------------------------------------------------------------- |
# | **Więcej epok** (200 vs 100)      | Lepszy test\_rmse w modelu głębokim                              | W modelu Średnim prowadziło do niestabilności (zbyt szybkie spadki/wybuchy)      |
# | **Umiarkowany dropout** (0.3–0.4) | Zdecydowanie obniżył overfitting, niskie cv\_r2\_std             | Zbyt duży (0.5) przy małym modelu podbił underfitting (Model wytrzymały RMSE≈56 k) |
# | **Duża szerokość** (512 HU)       | Duży potencjał reprezentacyjny, dobre RMSE                       | Jeżeli bez dropoutu → bardzo overfitował                                           |
# | **Wysoki LR** (0.1)               | Bardzo szybka zbieżność (Model szybki)                           | Niestabilność i wybuchy (cv\_r2\_mean≈0.39)                                        |
# | **Bardzo niski LR** (0.0001)      | Bardzo stabilne, małe wahania cv                                 | Nadmierny underfitting (RMSE>53 k)                                                 |
# | **Mały batch** (16)               | Bardzo drobne, częste aktualizacje → pomaga przy długim treningu | Wolniejsze uczenie (Widzimy czasy w głębokim, stablinym i wytrzymałym), wymaga więcej epok                                             |

# %% [markdown]
# Podsumowanie:
#
# - Umiarkowany dropout (0.2–0.3) znacząco obniżył test_RMSE, bo walczył z overfittingiem.
# - Więcej epok (200 vs 100) dało lepszą konwergencję dla większych modeli.
# - Większy batch size (64) stabilizował gradienty przy średnich LR
#
# - Zbyt wysoki LR (0.1) w połączeniu z dużym batch size wywoływał niestabilność
# - Zbyt duży dropout (0.5) w małych modelach prowadził do underfittingu (test_RMSE rosło).
# - Mały batch size (16) bez zwiększenia epok – wolne uczenie i niedostateczna konwergencja.
